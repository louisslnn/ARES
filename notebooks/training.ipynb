# %%
import pandas as pd
import os

# %%
train = pd.read_csv(os.path.join('../data/processed', 'train_relevant_features.csv'))
test = pd.read_csv(os.path.join('../data/processed', 'test_relevant_features.csv'))

y_train = train['RUL']
X_train = train.drop('RUL', axis=1)

y_test = test['RUL']
X_test = test.drop('RUL', axis=1)

# %%
y_train = y_train.clip(upper=125)

y_train
# Out:
# 0        125.0
# 1        125.0
# 2        125.0
# 3        125.0
# 4        125.0
#          ...
# 20626      4.0
# 20627      3.0
# 20628      2.0
# 20629      1.0
# 20630      0.0
# Name: RUL, Length: 20631, dtype: float64
